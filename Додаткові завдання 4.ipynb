# %% [markdown]
# # Додаткові завдання №4

# %% [markdown]
# ## Задача 1.2.15
# Нехай $\Omega = {1, 2, \ldots, 2n}$.
# Всiм числам приписанi ймовiрностi, пропорцiйнi логарифмам цих чисел.
# Знайти цi ймовiрностi.
# Знайти ймовiрнiсть того, що в результатi експерименту з’явиться:
# 1. парне число;
# 2. непарне число.

# %% [markdown]
# ### Завдання 1
# Реалізуйте випадкову величину, описану в умові задачі, за допомогою класу [scipy.stats.rv_discrete](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.rv_discrete.html) в залежності від параметра $n$.
#
# Створіть дві випадкові величини для:
# - $n = 10$;
# - $n = 25$.

# %%
# Місце для Вашого коду
import numpy as np
import math
from scipy.stats import rv_discrete
def do (n):
    s=0
    for i in range (1, 2*n+1):
        s+=(math.log(i))
    k=1/s
    l=[]
    for i in range (1, 2*n+1):
        l.append(k*math.log(i))
    return(l)
n1=np.array(do(10))
n2=np.array(do(25))
xi1=rv_discrete (a=1, b=20, values=(np.arange(1, 21), n1))
xi2=rv_discrete (a=1, b=20, values=(np.arange(1, 51), n2))

# %% [markdown]
# ### Завдання 2
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ значень отриманої випадкової величини в залежності від параметра $n$:
# - $n = 10$;
# - $n = 25$.

# %%
# Місце для Вашого коду
import matplotlib.pyplot as plt
x1=np.arange(0, 21, 1)
y1 = xi1.pmf(x1)
xi1_rvs=xi1.rvs(size=10000)
print(xi1_rvs)
plt.stem(x1, y1)
plt.show()
y1= xi1.cdf(x1)
plt.plot(x1, y1)
plt.show()
plt.hist(xi1_rvs)
plt.show()
x2=np.arange(0, 51, 1)
y2 = xi2.pmf(x2)
xi2_rvs=xi2.rvs(size=10000)
plt.stem(x2, y2)
plt.show()
y1= xi1.cdf(x2)
plt.plot(x2, y2)
plt.show()
plt.hist(xi2_rvs)
plt.show()
# Out:
# [ 5 15 15 ... 16 11  5]

# %% [markdown]
# ### Завдання 3
# Напишіть функцію для обрахунку теоретичної (через щільність отриманої випадкової величини) імовірності в залежності від параметра $n$.
#
# Виведіть результат для:
# - $n = 10$;
# - $n = 25$.

# %%
# Місце для Вашого коду

def p(n, x):
    if n==10:
        l=xi1.pmf(x)
    if n==25:
        l=xi2.pmf(x)
    return ('p={}'.format(l))
for i in range (1, 11):
    print (p(10, i))
for i in range (1, 11):
    print (p(25, i))
# Out:
# p=0.0
# p=0.01637267243297415
# p=0.025950071842855048
# p=0.0327453448659483
# p=0.038016168110510506
# p=0.042322744275829195
# p=0.04596390254194683
# p=0.04911801729892245
# p=0.051900143685710096
# p=0.05438884054348466
# p=0.0
# p=0.004668356716228672
# p=0.007399170335212202
# p=0.009336713432457344
# p=0.010839588616367463
# p=0.012067527051440872
# p=0.013105734205225235
# p=0.014005070148686015
# p=0.014798340670424404
# p=0.015507945332596137

# %% [markdown]
# ### Завдання 4
# Напишіть функцію для обрахунку еміричної (симулюванням $1000000$ значень отриманої випадкової величини) імовірності в залежності від параметра $n$.
#
# Виведіть результат для:
# - $n = 10$;
# - $n = 25$.

# %%
# Місце для Вашого коду
def p(n, x):
    if n==10:
        l=np.array(xi1.rvs(size=1000))
    if n==25:
        l=np.array(xi2.rvs(size=1000))
    x_=a = np.ones(1000)*x
    #print(x_)
    rez=np.sum(l==x_)
    
    return ('p={}'.format(rez/1000))
for i in range (1, 11):
    print (p(10, i))
for i in range (1, 11):
    print (p(25, i))
# Out:
# p=0.0
# p=0.011
# p=0.036
# p=0.031
# p=0.045
# p=0.042
# p=0.045
# p=0.044
# p=0.044
# p=0.053
# p=0.0
# p=0.002
# p=0.001
# p=0.009
# p=0.012
# p=0.015
# p=0.008
# p=0.012
# p=0.015
# p=0.021
