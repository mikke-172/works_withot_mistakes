# %% [markdown]
# # Домашня робота №3
# Будемо використовувати *Збірник задач з теорії ймовірностей та математичної статистики: навч. посібник / В.В. Голомозий, М.В. Карташов, К.В. Ральченко. – К.: Видавничо-поліграфічний центр «Київський університет», 2015. – 366 с.*
# Електронну версію збірника можна знайти [тут](http://probability.univ.kiev.ua/userfiles/kmv/gkr-problems.pdf).

# %% [markdown]
# ## 1 Задача 1.3.12
# Знайти ймовiрнiсть того, що серед трьох цифр, кожна з яких вибрана навмання, буде лише 1, 2, 3 рiзних.
#
# Обчисліть теоретичну (повним перебором) та еміричну (симулюванням $100000$ експериментів) імовірності.

# %%
# Місце для Вашого коду
import numpy as np
list_of_variants=[[]]
k=3
for i in range(k):
            new_list=[]
            for j in list_of_variants:

                for k in range(10):
                    p=j.copy()
                    new_list.append(p+[k])
                #new_list.append()
            list_of_variants=new_list.copy()     
#print(list_of_variants)    
n1=0
n2=0
n3=0
d=len(list_of_variants)
for i in list_of_variants:
    if len(set(i))==1:
        n1+=1
    if len(set(i))==2:
        n2+=1
    if len(set(i))==3:
        n3+=1
print('лише 1:{}; лише дві:{}; лише три:{}'.format(n1/d, n2/d, n3/d))   
list_of_variants=[]
q=100000
for j in range(q):
            list_of_variants.append(list(np.random.randint(low=0, high=10, size=3)))

n1=0
n2=0
n3=0
d=len(list_of_variants)
for i in list_of_variants:
    if len(set(i))==1:
        n1+=1
    if len(set(i))==2:
        n2+=1
    if len(set(i))==3:
        n3+=1
print('емпірично: лише 1:{}; лише дві:{}; лише три:{}'.format(n1/d, n2/d, n3/d))
# Out:
# лише 1:0.01; лише дві:0.27; лише три:0.72
# емпірично: лише 1:0.00966; лише дві:0.27124; лише три:0.7191

# %% [markdown]
# # 2 Задача 1.3.14
# З послiдовностi чисел $1, 2, . . . , n$ вибирають навмання $k$ рiзних чисел.
# Яка ймовiрнiсть того, що:
# 1. кожне з вибраних чисел кратне даному числу $p$;
# 2. кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел $p$ i $q$;
# 3. серед вибраних чисел є хоча б одне кратне $p$?
#
# Напишіть  відповідні функції для обрахунку теоретичної (повним перебором) та еміричної (симулюванням $100000$ експериментів) імовірностей в залежності від параметрів $n, k, p, q$.
# Виведіть результат для
# - $n = 25, k = 5, p = 3, q = 4$;
# - $n = 25, k = 10, p = 3, q = 4$.

# %%
# Місце для Вашого коду
from itertools import combinations
def teor (n, k, p, q):
    my_range=range(1,n+1)
    choose_k = list(combinations(my_range,k))
    n1, n2, n3=0, 0, 0
    d=len(choose_k)
    for i in choose_k:
        Flag1=True
        Flag2=True
        Flag3=False
        for j in i:
            if j%p==0:
                Flag3=True
            elif j%q==0:
                Flag1=False
            else:
                Flag1=False
                Flag2=False
        n1+=Flag1
        n2+=Flag2
        n3+=Flag3
    print ('кожне з вибраних чисел кратне даному числу  𝑝: {};  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :{}; серед вибраних чисел є хоча б одне кратне  𝑝 :{}'.format(n1/d, n2/d, n3/d)) 
teor(𝑛=25,𝑘=5,𝑝=3,𝑞=4) 
teor(𝑛=25,𝑘=10,𝑝=3,𝑞=4) 

def emp (n, k, p, q):
    my_range=range(1,n+1)
    choose_k =[]
    for i in range(10000):
        choose_k.append(list(np.random.choice(my_range, size=k, replace=False)))
    n1, n2, n3=0, 0, 0
    d=len(choose_k)
    for i in choose_k:
        Flag1=True
        Flag2=True
        Flag3=False
        for j in i:
            if j%p==0:
                Flag3=True
            elif j%q==0:
                Flag1=False
            else:
                Flag1=False
                Flag2=False
        n1+=Flag1
        n2+=Flag2
        n3+=Flag3
    print ('кожне з вибраних чисел кратне даному числу  𝑝: {};  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :{}; серед вибраних чисел є хоча б одне кратне  𝑝 :{}'.format(n1/d, n2/d, n3/d)) 
emp(𝑛=25,𝑘=5,𝑝=3,𝑞=4) 
emp(𝑛=25,𝑘=10,𝑝=3,𝑞=4)
# Out:
# кожне з вибраних чисел кратне даному числу  𝑝: 0.001054018445322793;  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :0.014906832298136646; серед вибраних чисел є хоча б одне кратне  𝑝 :0.8835309617918313
# кожне з вибраних чисел кратне даному числу  𝑝: 0.0;  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :2.0191142818683536e-05; серед вибраних чисел є хоча б одне кратне  𝑝 :0.9940503432494279
# кожне з вибраних чисел кратне даному числу  𝑝: 0.001;  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :0.0179; серед вибраних чисел є хоча б одне кратне  𝑝 :0.8844
# кожне з вибраних чисел кратне даному числу  𝑝: 0.0;  кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел  𝑝  i  𝑞 :0.0; серед вибраних чисел є хоча б одне кратне  𝑝 :0.9951

# %% [markdown]
# # 3 Задача 1.4.6
# В коморi знаходяться $n$ пар черевикiв.
# З них випадковим чином вибираються $2k$ черевикiв.
# Яка ймовiрнiсть того, що серед вибраних черевикiв:
# 1. вiдсутнi парнi;
# 2. є рiвно одна комплектна пара;
# 3. є двi комплектнi пари?
#
# Напишіть  відповідні функції для обрахунку теоретичної (повним перебором) та еміричної (симулюванням $100000$ експериментів) імовірностей в залежності від параметрів $n, k$.
# Виведіть результат для
# - $n = 8, k = 4$;
# - $n = 13, k = 5$.

# %%
# Місце для Вашого коду

def teor (n, k):
    chereviki=[]
    for i in range (n):
        chereviki.append(('П', i))
        chereviki.append(('Л', i))
    choose_k = list(combinations(chereviki,2*k))
    
    n1=0
    n2=0
    n3=0
    #print(choose_k)
    for i in choose_k:#комбінації з черевиків
        my_set=set()
        for j in i:#черевик в кожній комбінації
            my_set=my_set|{j[1]}
         #   print(my_set, i)
        if len(my_set)==2*k:
            n1+=1
            #print(my_set, i)
        elif len(my_set)==2*k-1:
            n2+=1
            #print(my_set, i)
        else:
            n3+=1
            #print(my_set, i)
    d=len (choose_k)
    print ('вiдсутнi парнi: {};  є рiвно одна комплектна пара:{}; є  (принаймні) двi комплектнi пари:{}'.format(n1/d, n2/d, n3/d)) 
teor(𝑛=8,𝑘=4) 
print('__')
teor(𝑛=13,𝑘=5)   
print('__')
# Out:
# вiдсутнi парнi: 0.01989121989121989;  є рiвно одна комплектна пара:0.2784770784770785; є  (принаймні) двi комплектнi пари:0.7016317016317016

# %%
def emp (n, k):
    chereviki=[]
    for i in range (n):
        chereviki.append(('П{}'.format(i)))
        chereviki.append(('Л{}'.format(i)))
    choose_k = []
    k2=2*k
    for i in range(10000):
        choose_k.append(list(np.random.choice(chereviki, size=k2, replace=False)))
    #print(choose_k)
    n1=0
    n2=0
    n3=0
    #print(choose_k)
    for i in choose_k:#комбінації з черевиків
        my_set=set()
        for j in i:#черевик в кожній комбінації
            my_set=my_set|{int(j[1:])}
            #print(my_set, i, 1)
        if len(my_set)==2*k:
            n1+=1
            #print(my_set, i, 2)
        elif len(my_set)==2*k-1:
            n2+=1
            #print(my_set, i, 3)
        else:
            n3+=1
            #print(my_set, i, 4)
    d=len (choose_k)
    print ('вiдсутнi парнi: {};  є рiвно одна комплектна пара:{}; є  (принаймні) двi комплектнi пари:{}'.format(n1/d, n2/d, n3/d)) 
emp(𝑛=8,𝑘=4)  
emp(𝑛=13,𝑘=5)
# Out:
# вiдсутнi парнi: 0.021;  є рiвно одна комплектна пара:0.278; є  (принаймні) двi комплектнi пари:0.701
# вiдсутнi парнi: 0.0594;  є рiвно одна комплектна пара:0.3025; є  (принаймні) двi комплектнi пари:0.6381

# %% [markdown]
# # 4 Задача 1.2.15
# Нехай $\Omega = {1, 2, \ldots, 2n}$.
# Всiм числам приписанi ймовiрностi, пропорцiйнi логарифмам цих чисел.
# Знайти цi ймовiрностi.
# Знайти ймовiрнiсть того, що в результатi експерименту з’явиться:
# 1. парне число;
# 2. непарне число.
#
# Напишіть функцію для обрахунку еміричної (симулюванням $100000$ експериментів) імовірності в залежності від параметра $n$.
# Виведіть результат для
# - $n = 10$;
# - $n = 25$.

# %%
# Місце для Вашого коду
import numpy as np
import math
def emp(n):
    s=0
    for i in range (1, 2*n+1):
        s+=(math.log(i))
    k=1/s
    l=[]
    for i in range (1, 2*n+1):
        l.append(k*math.log(i))
    print(l)
    n1=0
    n2=0
    d=10000
    for i in range(d):
        a=np.random.choice(range (1, 2*n+1), size=1, replace=False, p=l)
        if a%2==0:
            n1+=1
        else:
            n2+=1
    print('парне: {};  непарне:{};'.format(n1/d, n2/d))
emp(10)
emp(25)
# Out:
# [0.0, 0.01637267243297415, 0.025950071842855048, 0.0327453448659483, 0.038016168110510506, 0.042322744275829195, 0.04596390254194683, 0.04911801729892245, 0.051900143685710096, 0.05438884054348466, 0.05664014069622203, 0.05869541670880335, 0.0605860873630913, 0.062336574974920976, 0.06396623995336556, 0.0654906897318966, 0.06692269018174564, 0.06827281611868424, 0.06954992569663022, 0.0707615129764588]
# парне: 0.5242;  непарне:0.4758;
# [0.0, 0.004668356716228672, 0.007399170335212202, 0.009336713432457344, 0.010839588616367463, 0.012067527051440872, 0.013105734205225235, 0.014005070148686015, 0.014798340670424404, 0.015507945332596137, 0.016149860831199254, 0.016735883767669546, 0.0172749726111833, 0.017774090921453906, 0.018238758951579663, 0.01867342686491469, 0.01908173460728615, 0.019466697386653072, 0.019830840937436922, 0.020176302048824805, 0.02050490454043744, 0.020818217547427926, 0.021117600838835265, 0.021404240483898218, 0.021679177232734926, 0.021943329327411974, 0.022197511005636602, 0.02244244763768258, 0.02267878820591505, 0.02290711566780834, 0.023127955619109877, 0.02334178358114336, 0.023549031166411452, 0.023750091323514827, 0.023945322821592698, 0.024135054102881744, 0.024319586607313967, 0.024499197653665598, 0.024674142946395503, 0.02484465876505348, 0.025010963883303216, 0.02517326125666611, 0.025331739511648466, 0.025486574263656595, 0.025637929286791865, 0.025785957555063937, 0.025930802171618205, 0.02607259720012689, 0.02621146841045047, 0.026347533948963598]
# парне: 0.505;  непарне:0.495;
